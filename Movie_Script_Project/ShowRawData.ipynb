# %% [markdown]
# There are a bunch of interesting analysis done with the data available online. Below are some of them to help you with ideation of your final project.
#
# 1. [University of Washington News: New tool quantifies power imbalance between female and male characters in Hollywood movie scripts](https://www.washington.edu/news/2017/11/13/new-tool-quantifies-power-imbalance-between-female-and-male-characters-in-hollywood-movie-scripts/)
# 2. [Cornell University Paper: Chameleons in imagined conversations: A new approach to understanding coordination of linguistic style in dialogs](https://www.cs.cornell.edu/~cristian/Chameleons_in_imagined_conversations.html), and the corresponding [slide presentation](https://www.cs.cornell.edu/~cristian/Chameleons_in_imagined_conversations_files/chameleons_talk.pdf)
# 3. [Nature News: How movies mirror our mimicry](https://www.nature.com/news/2011/110624/full/news.2011.378.html)

# %%
import pandas as pd
import numpy as np
import pickle

# %%
df_dialog = pd.read_table(
    './movie-dialog-corpus/movie_lines.txt',
    delimiter='\t',
    error_bad_lines=False,
    warn_bad_lines=False,
    header=None,
    names=[
        'lineID',
        'characterID',
        'movieID',
        'character_name',
        'dialog'
    ]
)
# filter out invalid data
df_dialog = df_dialog[(df_dialog.character_name.notnull()) & (df_dialog.dialog.notnull())]
#print(df_dialog.head(5))
df_dialog_movie1 = df_dialog[df_dialog['characterID'] == 'u8599']
df_dialog_movie1
# Out:
#          lineID characterID movieID character_name dialog
# 289498  L624053       u8599    m583           KLAA

# %%
# Let's check the overall statistics of the data
df_dialog.describe()
# Out:
#          lineID characterID movieID character_name  dialog
# count    304352      304352  304352         304352  304352
# unique   304352        9031     617           5356  265579
# top     L490131       u4525    m289           JACK   What?
# freq          1         537    1530           3032    1680

# %% [markdown]
# There are a total of `304352` lines of dialoges spoken by `9031` unique characters across `617` different movies. In terms of character name, `JACK` seems to be very popular, but without further analysis, it's hard for us draw any conclusion on if it's due to very few movies that the character `JACK` really have spoken a lot, or that `JACK` is just the favorite choice of name shared among many different movies.
#
# `What?` is the most frequently used dialog. You might wonder `what?`, and I guess that reaction to some degree provided the intuition on why that's the case.

# %%
df_character = pd.read_table(
    './movie-dialog-corpus/movie_characters_metadata.txt',
    delimiter='\t',
    header=None,
    names=[
        'characterID',
        'character_name',
        'movieID',
        'movie_title',
        'gender',
        'position_in_credits'
    ]
)
k = df_character[df_character['characterID'] == 'u9032'].iloc[0,2]
#print(k)
df_movie = df_dialog[df_dialog['movieID'] == 'm589']
df_character_script = df_movie[df_movie['characterID'] == 'u0']
df_movie
# Out:
#          lineID characterID movieID character_name  \
# 292291  L634094       u8682    m589      BLIND MAN
# 292292  L634093       u8683    m589          BOBBY
# 292293  L634092       u8682    m589      BLIND MAN
# 292294  L634091       u8683    m589          BOBBY
# 292295  L634087       u8683    m589          BOBBY
# 292296  L634086       u8682    m589      BLIND MAN
# 292297  L634085       u8683    m589          BOBBY
# 292298  L634084       u8682    m589      BLIND MAN
# 292299  L634083       u8683    m589          BOBBY
# 292300  L634082       u8682    m589      BLIND MAN
# 292301  L634081       u8683    m589          BOBBY
# 292302  L634080       u8682    m589      BLIND MAN
# 292303  L634079       u8683    m589          BOBBY
# 292304  L634078       u8682    m589      BLIND MAN
# 292305  L634077       u8683    m589          BOBBY
# 292306  L634076       u8682    m589      BLIND MAN
# 292307  L633906       u8682    m589      BLIND MAN
# 292308  L633905       u8683    m589          BOBBY
# 292309  L633904       u8682    m589      BLIND MAN
# 292310  L633903       u8683    m589          BOBBY
# 292311  L633902       u8682    m589      BLIND MAN
# 292312  L633901       u8683    m589          BOBBY
# 292313  L633900       u8682    m589      BLIND MAN
# 292314  L633899       u8683    m589          BOBBY
# 292315  L633898       u8682    m589      BLIND MAN
# 292316  L633897       u8683    m589          BOBBY
# 292317  L633896       u8682    m589      BLIND MAN
# 292318  L633894       u8682    m589      BLIND MAN
# 292319  L633893       u8683    m589          BOBBY
# 292320  L633892       u8682    m589      BLIND MAN
# ...         ...         ...     ...            ...
# 292994  L634073       u8687    m589          GRACE
# 292995  L634072       u8688    m589           JAKE
# 292996  L634071       u8687    m589          GRACE
# 292997  L634070       u8688    m589           JAKE
# 292998  L634069       u8687    m589          GRACE
# 292999  L634068       u8688    m589           JAKE
# 293000  L634067       u8687    m589          GRACE
# 293001  L634066       u8688    m589           JAKE
# 293002  L634065       u8687    m589          GRACE
# 293003  L634064       u8688    m589           JAKE
# 293004  L634063       u8687    m589          GRACE
# 293005  L634062       u8688    m589           JAKE
# 293006  L634030       u8693    m589           TOBY
# 293007  L634029       u8689    m589          JENNY
# 293008  L633937       u8693    m589           TOBY
# 293009  L633936       u8689    m589          JENNY
# 293010  L633672       u8693    m589           TOBY
# 293011  L633671       u8689    m589          JENNY
# 293012  L633667       u8693    m589           TOBY
# 293013  L633666       u8689    m589          JENNY
# 293014  L633665       u8693    m589           TOBY
# 293015  L634023       u8691    m589         SERGEI
# 293016  L634022       u8692    m589        SHERIFF
# 293017  L634021       u8691    m589         SERGEI
# 293018  L634020       u8692    m589        SHERIFF
# 293019  L634019       u8692    m589        SHERIFF
# 293020  L634018       u8691    m589         SERGEI
# 293021  L634017       u8692    m589        SHERIFF
# 293022  L634016       u8691    m589         SERGEI
# 293023  L634015       u8692    m589        SHERIFF
#
#                                                    dialog
# 292291                    You know I won't be seeing you.
# 292292  You <u>are</u> crazy you know. Be seeing you o...
# 292293  Things ain't always the way they seem. You got...
# 292294               Time's up. Any last words of wisdom?
# 292295  You got a lotta philosophy in you old timer bu...
# 292296  Well don't say I didn't warn you when things g...
# 292297     No and I don't plan on sticking around either.
# 292298  Nothing makes the Great Spirit laugh harder th...
# 292299                Not this twig friend.  I got plans.
# 292300                                      More or less.
# 292301  So we're all just floating along like twigs in...
# 292302  Afraid of it?  Boy I live in the dark. All cau...
# 292303                            You afraid of the dark?
# 292304  Night is when you want to sleep but the dry he...
# 292305  Difference between you and me old man is I see...
# 292306  Ain't over yet.  Night is part of day; separat...
# 292307           Your lies are old but you tell 'em well.
# 292308  I'm a little short Pops. I'll catch you next t...
# 292309  ...But ain't you got a little something for th...
# 292310                                I got things to do.
# 292311  Well people gotta get by somehow. That's the c...
# 292312  Musta been some bad ass nuclear tests here in ...
# 292313  So now you're going to tell me where I lost my...
# 292314  I thought you said you lost your eyes in the war?
# 292315  All them miners last century. Hungry ghosts ki...
# 292316                                      Who's cursed?
# 292317  Cocksucker motherfucker! Cops. I hear you. Alw...
# 292318                  ...And everything is nothing too.
# 292319                                              What?
# 292320  Seems like I do but only cause end of the day ...
# ...                                                   ...
# 292994                 Nothing Jake.  Absolutely nothing.
# 292995                 What the hell you looking at girl?
# 292996  I picked them out for you Jake.  I thought you...
# 292997                                    They look nice.
# 292998              You haven't even looked at them once.
# 292999                                    They look nice.
# 293000        You never said anything.  About the drapes.
# 293001  I know.  I was here when your apprentice was h...
# 293002                          I put up new drapes Jake.
# 293003  You spent a long time talking for a wrong numb...
# 293004                                      Wrong number.
# 293005                         Who was that on the phone?
# 293006  You stay away Jenny.  I aim to mess him up and...
# 293007                Toby!  Toby Tucker leave him alone!
# 293008                                    I said come on!
# 293009                                    I want to stay.
# 293010  Stay out of this Jenny.  We got man's business...
# 293011  Honest Toby.  I just axed him for a quarter fo...
# 293012  You shut your mouth girl and get back over to ...
# 293013  Aw Toby we weren't doing nothing.  We was just...
# 293014                             I axed you a question.
# 293015                                  I want my lawyer!
# 293016  Get out of the car spread them. You can jawbon...
# 293017  What fuckin grocery store you fucking shithead...
# 293018  What's that?  ...""concealed"" is a definite n...
# 293019  What? You trying to bribe me mister? Just caus...
# 293020  I am Russian da! I am also <u>rich</u> Russian...
# 293021  Whoa what kind of accent you got there? You on...
# 293022  Vat? I am going 5 miles an hour! I am looking ...
# 293023  Where's the fire sweetheart? Don't know how th...
#
# [733 rows x 5 columns]

# %%
# Let's first see the overall stats
df_character.describe()
# Out:
#        characterID character_name movieID movie_title gender  \
# count         9035           9033    9035        9035   9035
# unique        9035           5354     617         617      3
# top          u7306            MAN    m289      casino      ?
# freq             1             44      44          44   6020
#
#        position_in_credits
# count                 9035
# unique                  58
# top                      ?
# freq                  6339

# %%
# Let's see what the gender stats looks like
df_character.gender.value_counts()
# Out:
# ?    6020
# M    2049
# F     966
# Name: gender, dtype: int64

# %% [markdown]
# Unfortunately, near $2/3$ a lot of the gender information is not available in the dataset (`6020` out of `9035`). However, we still have $1/3$ of the data and that's still `~3000` characters so it's definitely enough for any analysis that takes the prospective of gender.

# %%
with open('./movie-dialog-corpus/movie_title.pkl', 'rb') as f:
    df_title = pickle.load(f)

df_title.drop(['genres_x', 'movie_title'], axis='columns', inplace=True)
df_title.rename({'genres_y' : 'genres', 'title' : 'movie_title'}, axis='columns', inplace=True)

# add release month
def parse_month(x):
    if type(x) is str:
        return np.int8(x[5:7])
    return np.nan
df_title['release_month'] = df_title.release_date.apply(parse_month)
#sdf = df_title.sort_values('budget')
#sdf.tail()
df_title[df_title['movieID'] == 'm589']
# Out:
#     movieID  movie_year  IMDB_rating  IMDB_votes  budget  \
# 589    m589        1997          6.7       25388     0.0
#
#                                         genres    imdb_id original_language  \
# 589  [Action, Comedy, Thriller, Crime, Family]  tt0098536                en
#
#      original_title                                           overview  \
# 589  Turner & Hooch  Scott Turner has 3 days left in the local poli...
#
#          ...       production_countries release_date     revenue  runtime  \
# 589      ...                       [US]   1989-07-28  71079915.0    100.0
#
#      spoken_languages    status                            tagline  \
# 589              [en]  Released  The Oddest Couple Ever Unleashed!
#
#         movie_title                          production_companies_name  \
# 589  Turner & Hooch  [Silver Screen Partners III, Touchstone Pictures]
#
#     release_month
# 589           7.0
#
# [1 rows x 21 columns]

# %%
# Overall stats
df_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 617 entries, 0 to 616
# Data columns (total 21 columns):
# movieID                      617 non-null object
# movie_year                   617 non-null int64
# IMDB_rating                  617 non-null float64
# IMDB_votes                   617 non-null int64
# budget                       616 non-null float64
# genres                       616 non-null object
# imdb_id                      616 non-null object
# original_language            616 non-null object
# original_title               616 non-null object
# overview                     616 non-null object
# popularity                   616 non-null float64
# production_countries         616 non-null object
# release_date                 616 non-null object
# revenue                      616 non-null float64
# runtime                      614 non-null float64
# spoken_languages             616 non-null object
# status                       616 non-null object
# tagline                      616 non-null object
# movie_title                  616 non-null object
# production_companies_name    616 non-null object
# release_month                616 non-null float64
# dtypes: float64(6), int64(2), object(13)
# memory usage: 106.0+ KB

# %% [markdown]
# There are `617` total movies and we have full data for `616` of them (only one missing). There are a lot of different features describing a movie that you can analyze.
